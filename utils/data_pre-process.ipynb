# %%
import pandas as pd
import datetime
import os
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../data/electricity_data/2E.csv')
thresh = 1000
mask = (df['val'] > 0) & (df['val'] < thresh)
df = df.reset_index()
df = df[mask]
df.to_csv("./test.csv")
plt.plot(df['index'], df['val'])
df.columns
# Out:
# Index(['index', 'metric', 'time', 'val'], dtype='object')

# %%
df = pd.read_csv('../data/electricity_data/1A.csv')
mask = df['val'] > 0
date_thresh = 2022061623
df = df[mask]
df['time'] = pd.to_datetime(df['time'])
df['time'] = int(df['time'].dt.strftime('%Y%m%d%H'))
df = df[df['time'] < date_thresh]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       4 df = df[mask]
#       5 df['time'] = pd.to_datetime(df['time'])
# ----> 6 df['time'] = int(df['time'].dt.strftime('%Y%m%d%H'))
#       7 df = df[df['time'] < date_thresh]
#
# File D:\Users\24105\anaconda3\envs\ECE445_env\lib\site-packages\pandas\core\series.py:191, in _coerce_method.<locals>.wrapper(self)
#     189 if len(self) == 1:
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
dataset = pd.concat((df_wtr, hourly_ele['p_shehui']), axis=1)

# %%
dataset.to_csv('../dataset/train_dataset/jinhua.csv')
